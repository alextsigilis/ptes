# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, OneHotEncoder, LabelEncoder
from sklearn.metrics import cohen_kappa_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.decomposition import PCA

# %%
data = pd.read_csv('Features.csv')
data.dropna()
# Out:
#         epoch      mean       std   skewness      entr  sqrt_entr  num_peaks  \
# 0           1  0.009029  0.047305  10.811985  1.440600   1.439525         79
# 1           2  0.014787  0.059345   7.648483  1.823303   1.821998         96
# 2           3  0.012924  0.054213   7.497664  1.617883   1.616605         85
# 3           4  0.012937  0.055270   8.035735  1.639611   1.638333         73
# 4           5  0.012772  0.059273   8.208528  1.532794   1.531516         66
# ...       ...       ...       ...        ...       ...        ...        ...
# 135264    859  0.009305  0.054670   9.795810  1.044953   1.044416         54
# 135265    860  0.010310  0.051489   8.343153  1.250293   1.249552         69
# 135266    861  0.011932  0.063091   8.123224  1.145127   1.145127         64
# 135267    862  0.005477  0.032993  13.427733  0.932899   0.932362         47
# 135268    863  0.021210  0.071943   6.418136  2.177035   2.175088         91
#
#         mean_peak_int    x_mean    y_mean      annotation
# 0            0.105237  1.117442  0.685031   Sleep stage W
# 1            0.188235  1.349906  0.839022   Sleep stage W
# 2            0.173333  1.199140  0.703843   Sleep stage W
# 3            0.174698  1.004031  0.679387   Sleep stage W
# 4            0.220202  0.946251  0.594195   Sleep stage W
# ...               ...       ...       ...             ...
# 135264       0.133624  0.792798  0.537490  Sleep stage N2
# 135265       0.143620  1.013437  0.625638  Sleep stage N2
# 135266       0.158578  0.923408  0.586402  Sleep stage N2
# 135267       0.128744  0.700349  0.473260  Sleep stage N1
# 135268       0.212066  1.253964  0.748186   Sleep stage W
#
# [135269 rows x 11 columns]

# %%
group = data.groupby(['annotation'])
col = "mean"
group[col].hist(legend=True)
# Out:
# annotation
# Sleep stage N1    Axes(0.125,0.11;0.775x0.77)
# Sleep stage N2    Axes(0.125,0.11;0.775x0.77)
# Sleep stage N3    Axes(0.125,0.11;0.775x0.77)
# Sleep stage R     Axes(0.125,0.11;0.775x0.77)
# Sleep stage W     Axes(0.125,0.11;0.775x0.77)
# Name: mean, dtype: object
